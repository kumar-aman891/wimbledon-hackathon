# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

sys.path.append(str(project_root))

# %%
from src.data.load_historical_matches import (
    load_historical_matches
)

df = load_historical_matches()

df.shape
# Out:
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2015.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2016.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2017.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2018.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2019.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2020.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2021.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2022.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2023.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2024.csv
# D:\Office-work\Exl\ML HAckathon\wimbledon-hackathon\data\raw\atp\atp_matches_2025.csv
# (30616, 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30616 entries, 0 to 30615
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          30616 non-null  object
#  1   tourney_name        30616 non-null  object
#  2   surface             30563 non-null  object
#  3   draw_size           30616 non-null  int64
#  4   tourney_level       30616 non-null  object
#  5   tourney_date        30616 non-null  int64
#  6   match_num           30616 non-null  int64
#  7   winner_id           30616 non-null  int64
#  8   winner_seed         12947 non-null  float64
#  9   winner_entry        4429 non-null   object
#  10  winner_name         30616 non-null  object
#  11  winner_hand         30616 non-null  object
#  12  winner_ht           30384 non-null  float64
#  13  winner_ioc          30616 non-null  object
#  14  winner_age          30610 non-null  float64
#  15  loser_id            30616 non-null  int64
#  16  loser_seed          7532 non-null   float64
#  17  loser_entry         6885 non-null   object
#  18  loser_name          30616 non-null  object
#  19  loser_hand          30612 non-null  object
#  20  loser_ht            30060 non-null  float64
#  21  loser_ioc           30616 non-null  object
#  22  loser_age           30608 non-null  float64
#  23  score               30616 non-null  object
#  24  best_of             30616 non-null  int64
#  25  round               30616 non-null  object
#  26  minutes             27494 non-null  float64
#  27  w_ace               29274 non-null  float64
#  28  w_df                29274 non-null  float64
#  29  w_svpt              29274 non-null  float64
#  30  w_1stIn             29274 non-null  float64
#  31  w_1stWon            29274 non-null  float64
#  32  w_2ndWon            29274 non-null  float64
#  33  w_SvGms             29274 non-null  float64
#  34  w_bpSaved           29274 non-null  float64
#  35  w_bpFaced           29274 non-null  float64
#  36  l_ace               29274 non-null  float64
#  37  l_df                29274 non-null  float64
#  38  l_svpt              29274 non-null  float64
#  39  l_1stIn             29274 non-null  float64
#  40  l_1stWon            29274 non-null  float64
#  41  l_2ndWon            29274 non-null  float64
#  42  l_SvGms             29274 non-null  float64
#  43  l_bpSaved           29274 non-null  float64
#  44  l_bpFaced           29274 non-null  float64
#  45  winner_rank         30465 non-null  float64
#  46  winner_rank_points  30465 non-null  float64
#  47  loser_rank          30205 non-null  float64
#  48  loser_rank_points   30205 non-null  float64
#  49  match_year          30616 non-null  int64
# dtypes: float64(29), int64(7), object(14)
# memory usage: 11.7+ MB

# %%
df.isnull().sum().sort_values(
    ascending=False
).head(20)
# Out:
# winner_entry    26187
# loser_entry     23731
# loser_seed      23084
# winner_seed     17669
# minutes          3122
# l_ace            1342
# l_svpt           1342
# l_1stIn          1342
# l_1stWon         1342
# l_df             1342
# w_1stIn          1342
# w_ace            1342
# w_df             1342
# w_svpt           1342
# w_2ndWon         1342
# w_1stWon         1342
# w_SvGms          1342
# l_2ndWon         1342
# l_SvGms          1342
# l_bpSaved        1342
# dtype: int64

# %%
df["surface"].value_counts()
# Out:
# surface
# Hard      18152
# Clay       9164
# Grass      3228
# Carpet       19
# Name: count, dtype: int64

# %%
df["tourney_level"].value_counts()
# Out:
# tourney_level
# A    16250
# M     6196
# G     5461
# D     2403
# F      242
# O       64
# Name: count, dtype: int64

# %%
df["tourney_level"].value_counts()
# Out:
# tourney_level
# A    16250
# M     6196
# G     5461
# D     2403
# F      242
# O       64
# Name: count, dtype: int64

# %%
df.isnull().sum().sort_values(
    ascending=False
).head(20)
# Out:
# winner_entry    26187
# loser_entry     23731
# loser_seed      23084
# winner_seed     17669
# minutes          3122
# l_ace            1342
# l_svpt           1342
# l_1stIn          1342
# l_1stWon         1342
# l_df             1342
# w_1stIn          1342
# w_ace            1342
# w_df             1342
# w_svpt           1342
# w_2ndWon         1342
# w_1stWon         1342
# w_SvGms          1342
# l_2ndWon         1342
# l_SvGms          1342
# l_bpSaved        1342
# dtype: int64

# %%
df[
    [
        "tourney_name",
        "surface",
        "winner_name",
        "loser_name",
        "winner_rank",
        "loser_rank"
    ]
].head()
# Out:
#   tourney_name surface      winner_name      loser_name  winner_rank  \
# 0     Brisbane    Hard     John Millman  Rhyne Williams        153.0
# 1     Brisbane    Hard  Jarkko Nieminen     Denis Kudla         73.0
# 2     Brisbane    Hard  James Duckworth    Gilles Simon        125.0
# 3     Brisbane    Hard    Jeremy Chardy  Andrey Golubev         31.0
# 4     Brisbane    Hard    Martin Klizan   Jurgen Melzer         34.0
#
#    loser_rank
# 0       220.0
# 1       123.0
# 2        21.0
# 3        72.0
# 4       110.0

# %%
import pandas as pd

df = pd.read_parquet(
    
)

df.sort_values(
    "overall_elo",
    ascending=False
).head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_parquet(
#       4     "\data\processed\current_elo.parquet"
#       5 )
#       7 df.sort_values(
#       8     "overall_elo",
#       9     ascending=False
#      10 ).head(20)
#
# File c:\Users\kumar\anaconda3\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File c:\Users\kumar\anaconda3\Lib\site-packages\pandas\io\parquet.py:267, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     264 if manager == "array":
#     265     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 267 path_or_handle, handles, filesystem = _get_path_or_handle(
#     268     path,
#     269     filesystem,
#     270     storage_options=storage_options,
#     271     mode="rb",
#     272 )
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
#
# File c:\Users\kumar\anaconda3\Lib\site-packages\pandas\io\parquet.py:140, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     130 handles = None
#     131 if (
#     132     not fs
#     133     and not is_dir
#    (...)
#     138     # fsspec resources can also point to directories
#     139     # this branch is used for example when reading from non-fsspec URLs
# --> 140     handles = get_handle(
#     141         path_or_handle, mode, is_text=False, storage_options=storage_options
#     142     )
#     143     fs = None
#     144     path_or_handle = handles.handle
#
# File c:\Users\kumar\anaconda3\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\data\\processed\\current_elo.parquet'
